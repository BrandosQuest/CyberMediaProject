# %%
# !pip install --no-deps -U "git+https://github.com/facebookresearch/demucs#egg=demucs"
# !pip install soundfile musdb
# Out:
# Collecting demucs
#   Cloning https://github.com/facebookresearch/demucs to c:\users\brando\appdata\local\temp\pip-install-3ywsdas0\demucs_00d8655515714ac1ba335f802f8f26cb
#   Resolved https://github.com/facebookresearch/demucs to commit e976d93ecc3865e5757426930257e200846a520a
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/demucs 'C:\Users\Brando\AppData\Local\Temp\pip-install-3ywsdas0\demucs_00d8655515714ac1ba335f802f8f26cb'
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Brando\AppData\Local\Python\pythoncore-3.11-64\python.exe -m pip install --upgrade pip
# Requirement already satisfied: soundfile in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (0.13.1)
# Requirement already satisfied: musdb in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (0.4.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from soundfile) (1.26.4)
# Requirement already satisfied: stempeg>=0.2.4 in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from musdb) (0.2.6)
# Requirement already satisfied: pyaml in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from musdb) (26.2.1)
# Requirement already satisfied: tqdm in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from musdb) (4.67.3)
# Requirement already satisfied: pycparser in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: ffmpeg-python>=0.2.0 in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from stempeg>=0.2.4->musdb) (0.2.0)
# Requirement already satisfied: PyYAML in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from pyaml->musdb) (6.0.3)
# Requirement already satisfied: colorama in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from tqdm->musdb) (0.4.6)
# Requirement already satisfied: future in c:\users\brando\appdata\local\python\pythoncore-3.11-64\lib\site-packages (from ffmpeg-python>=0.2.0->stempeg>=0.2.4->musdb) (1.0.0)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Brando\AppData\Local\Python\pythoncore-3.11-64\python.exe -m pip install --upgrade pip

# %%
import demucs.api
import soundfile as sf
import torch
import musdb
import IPython.display as ipd
import os

# %%
noisy = False
mus = musdb.DB(download=True)
track = mus[0]

choice = input("Do you want to load a noisy track? (y/n): ")

if choice.lower() == "y":
    noisy_path = './songs/testSample_noisy.wav'
    if os.path.exists(noisy_path):
        audio, sr = sf.read(noisy_path)
        noisy = True
    else:
        print("File not found! Loading clean track instead...")
        audio = track.audio
        sr = track.rate
elif choice.lower() == "n":
    audio = track.audio
    sr = track.rate
else:
    audio = track.audio
    sr = track.rate

# Convert to PyTorch tensor for Demucs ([samples, channels] -> [channels, samples])
wav_tensor = torch.tensor(audio).T.float()

# Demucs requires stereo audio. If mono, duplicate the channel to fake stereo.
if wav_tensor.ndim == 1:
    wav_tensor = wav_tensor.unsqueeze(0).repeat(2, 1)

print(f"Audio loaded! Tensor shape: {wav_tensor.shape} | Sample Rate: {sr} Hz")
# Out:
# Do you want to load a noisy track? (y/n):  y
# Audio loaded! Tensor shape: torch.Size([2, 300032]) | Sample Rate: 44100 Hz

# %%
# !mkdir output
# Out:
# A subdirectory or file output already exists.

# %%
for name, tensor in separated.items():
    audio_numpy = tensor.numpy()

    print(f"Displaying {name}")
    ipd.display(ipd.Audio(audio_numpy, rate=sample_rate))

    name_file = f"test_{name}.wav"
    sf.write("./output/" + name_file, audio_numpy.T, sample_rate, format='WAV')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for name, tensor in separated.items():
#       2     audio_numpy = tensor.numpy()
#       4     print(f"Displaying {name}")
#
# NameError: name 'separated' is not defined
