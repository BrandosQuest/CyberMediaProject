# %% [markdown]
# <a href="https://colab.research.google.com/github/BrandosQuest/CyberMediaProject/blob/master/utils.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def white_noise(mean, std, num_samples):
  samples = np.random.normal(mean, std, size=num_samples)

  plt.plot(samples)
  plt.show()

  return samples

# %%
white_noise(0, 1, 3000)
# Out:
# array([ 0.78468335,  0.5972018 , -0.14685652, ...,  1.45275637,
#         0.20266488,  0.53264851])

# %%
def add_white_noise(signal, snr_db):
  sig_power = np.mean(signal**2)
  snr = 10**(snr_db/10)
  noise_power = sig_power/snr

  noise = np.random.normal(0, np.sqrt(noise_power), len(signal))

  return signal + noise

# %%
fs = 44100
t = np.linspace(0, 1, fs)
audio = 0.5 * np.sin(2 * np.pi * 440 * t)

test = add_white_noise(audio, snr_db=10)

plt.figure(figsize=(10, 4))
plt.plot(t[:1000], test[:1000])
plt.title("Sine Wave with Gaussian White Noise")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.grid(True)
plt.show()
