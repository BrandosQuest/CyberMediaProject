# %%
# !pip install --no-deps -U "git+https://github.com/facebookresearch/demucs#egg=demucs"
# !pip install soundfile musdb
# Out:
# Collecting demucs
#   Cloning https://github.com/facebookresearch/demucs to /tmp/pip-install-oqo3cnwn/demucs_b6cbc30fee4246549a653ef86c9792b1
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/demucs /tmp/pip-install-oqo3cnwn/demucs_b6cbc30fee4246549a653ef86c9792b1
#   Resolved https://github.com/facebookresearch/demucs to commit e976d93ecc3865e5757426930257e200846a520a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (0.13.1)
# Requirement already satisfied: musdb in /usr/local/lib/python3.12/dist-packages (0.4.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: stempeg>=0.2.4 in /usr/local/lib/python3.12/dist-packages (from musdb) (0.2.6)
# Requirement already satisfied: pyaml in /usr/local/lib/python3.12/dist-packages (from musdb) (26.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from musdb) (4.67.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile) (3.0)
# Requirement already satisfied: ffmpeg-python>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from stempeg>=0.2.4->musdb) (0.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from pyaml->musdb) (6.0.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python>=0.2.0->stempeg>=0.2.4->musdb) (1.0.0)

# %%
import demucs.api
import soundfile as sf
import torch
import musdb
import IPython.display as ipd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10064/1176260410.py in <cell line: 0>()
# ----> 1 import demucs.api
#       2 import soundfile as sf
#       3 import torch
#       4 import musdb
#       5 import IPython.display as ipd
#
# /usr/local/lib/python3.12/dist-packages/demucs/api.py in <module>
#      26 import torchaudio as ta
#      27
# ---> 28 from dora.log import fatal
#      29 from pathlib import Path
#      30 from typing import Optional, Callable, Dict, Tuple, Union
#
# ModuleNotFoundError: No module named 'dora'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
noisy = False
mus = musdb.DB(download=True)
track = mus[0]

choice = input("Do you want to load a noisy track? (y/n): ")

if choice.lower() == "y":
    noisy_path = './songs/testSample_noisy.wav'
    if os.path.exists(noisy_path):
        audio, sr = sf.read(noisy_path)
        noisy = True
    else:
        print("File not found! Loading clean track instead...")
        audio = track.audio
        sr = track.rate
elif choice.lower() == "n":
    audio = track.audio
    sr = track.rate
else:
    audio = track.audio
    sr = track.rate

# Convert to PyTorch tensor for Demucs ([samples, channels] -> [channels, samples])
wav_tensor = torch.tensor(audio).T.float()

# Demucs requires stereo audio. If mono, duplicate the channel to fake stereo.
if wav_tensor.ndim == 1:
    wav_tensor = wav_tensor.unsqueeze(0).repeat(2, 1)

print(f"Audio loaded! Tensor shape: {wav_tensor.shape} | Sample Rate: {sr} Hz")

# %%
# !mkdir output

# %%
for name, tensor in separated.items():
    audio_numpy = tensor.numpy()

    print(f"Displaying {name}")
    ipd.display(ipd.Audio(audio_numpy, rate=sample_rate))

    name_file = f"test_{name}.wav"
    sf.write("./output/" + name_file, audio_numpy.T, sample_rate, format='WAV')
